# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
#
# ----------------------------------------------------------------------------------
#
# Normaler Text
#
#     Ein Code-Block
#     durch Einrückung
#     mit vier Leerzeichen
#
# ----------------------------------------------------------------------------------
#
# Zwei oder mehr Leerzeichen am Ende der Zeile
# erzeugen einen Zeilenumbruch.
#
# ----------------------------------------------------------------------------------
#
# > This is a blockquote.
# >
# > This is the second paragraph in the blockquote.
# >
# > ## This is an H2 in a blockquote
#
# ----------------------------------------------------------------------------------
#
# Inline Quelltext colored:
#
# ```python
# %%writefile <file name>
# ```
#
# ----------------------------------------------------------------------------------
#
# Link mit title attribute:
#
# [example link](http://example.com/ "With a Title")
#
# ----------------------------------------------------------------------------------
#
# Listings:
#
# * Ein Punkt in einer ungeordneten Liste
# * Ein weiterer Punkt in einer ungeordneten Liste
#     * Ein Unterpunkt, um vier Leerzeichen eingerückt
# * Statt * funktionieren auch + oder -
#
# ist gleich
#
# + Ein Punkt in einer ungeordneten Liste
# + Ein weiterer Punkt in einer ungeordneten Liste
#     + Ein Unterpunkt, um vier Leerzeichen eingerückt
# + Statt * funktionieren auch + oder -
#
# und ist auch gleich
#
# - Ein Punkt in einer ungeordneten Liste
# - Ein weiterer Punkt in einer ungeordneten Liste
#     - Ein Unterpunkt, um vier Leerzeichen eingerückt
# - Statt * funktionieren auch + oder -
#
#
# 1. Ein Punkt in einer geordneten Liste
# 2. Ein weiterer Punkt; bei der Eingabe muss nicht auf irgendeine Reihenfolge geachtet werden, sondern nur darauf, dass es beliebige Ziffern sind
# 1. Noch ein Punkt, der zeigt, dass auch die mehrfache Angabe derselben Ziffer möglich ist
#
#
# *Kursiv*, **Fett** und ***Fett kursiv*** bzw.
#
# _Kursiv_, __Fett__ und ___Fett kursiv___
#
# ----------------------------------------------------------------------------------
#
# Reference-style links allow you to refer to your links by names, which you define elsewhere
# in your document:
#
# I get 10 times more traffic from [Google][1] than from
# [Yahoo][2] or [MSN][3].
#
# [1]: http://google.com/        "Google"
# [2]: http://search.yahoo.com/  "Yahoo Search"
# [3]: http://search.msn.com/    "MSN Search"
#
# ----------------------------------------------------------------------------------
#
# Inline images:
#
# ![alternative text for image](plot_contour_small.png "title of the image")
#
# ----------------------------------------------------------------------------------
#
# Reference-style:
#
# ![alternative text for reference][4]
#
# [4]: plot_contour_small.png "title of reference"
#
#
# Tabelle:
#
# |  | title 1 | title 2 |
# | -- | -- | -- |
# | row 0 | val 1 | val 2 |
# | row 1 | val 3 | val 4 |
#
#
# || Left-aligned | Center-aligned | Right-aligned |
# | :-------------| :------------: | ------------: |
# |  git status   | git status     | git status    |
# |  git diff     | git diff       | git diff      |
#
#
# ----------------------------------------------------------------------------------
#
# Durchstreichen mit \~\~:
#
# ~~Falscher Text~~
#
# ----------------------------------------------------------------------------------
#
#
#
# ----------------------------------------------------------------------------------

# %% [markdown]
# Latex equations:
#
# $e^{i\pi} + 1 = 0$

# %% [markdown]
# <video controls src="/Users/k204045/Movies/spiral_NH_RCP8.5_2006-2100_labelbar_slider_global_mean.mp4" />
